# %%
from matrix import*  
from solver import *
from pedestrian import* 
from matplotlib import pyplot as plt
import timeit
import numpy as np


#step 1 setup beam and pedestrians
#beam
numElements = 10  # n - Number of beam elements !not for modal
length = 50  # L - Length (m)
width = 2  # b - Width (m)
height = 0.6  # h - Height (m)
E = 200e9  # E - Young's modulus (N/m^2)
modalDampingRatio = 0.005  # xi - Modal damping ratio of the beam
nHigh = 3  # nHigh - Higher mode for damping matrix
beamFreq =2 #Hz
area = 0.3162  # A - Cross-section area (m^2)
linearMass = 500  # m - Linear mass (kg/m)
x_interested= length/2
numbers = 3
#ped
numped = 2
pedmass = 80     #kg
peddamp = .3    
#pedstiff = 25000 #N/m
pedpace  = 2     #Hz
pedphase = 0
pedInlocation = 0
pedvelocity = 1.25
pedBodyF= 2 #Hz

#ped
kped1=(2*np.pi*pedBodyF)**2*pedmass
cped1 = (2*np.pi*pedBodyF)*2*peddamp*pedmass

#mat=np.zeros(1,numped) #to be extended into probabilistic inputs
mped=np.array([pedmass,pedmass])
cped = np.array([cped1,cped1])
kped = np.array([kped1,kped1])

#bridge
modulus =linearMass * ((2 * math.pi * beamFreq) * (math.pi / length) ** (-2)) ** 2  #E*(width*height**3)/12

#set time info
hht=0.01

#initial possition vector.......formultiple ped all these would become matrices

#xrb=np.zeros(1,numped)
xrb=[0,-1]

Bridge = bridge(   
    length = length,                 # m
    modulus = modulus,               # N m^2
    density = linearMass,            # kg/m
    damp    = modalDampingRatio ,    #%
    numbers = 3,  )                   #modes


Human = Pedestrian(
         mass = pedmass,     #kg
         damp = peddamp ,   #%
         stiff = kped, #N/m
         pace  = pedpace ,    #Hz
         phase = pedphase,
         location = pedInlocation,
         velocity = pedvelocity,
         
         iSync=0)

# %%
_,_,ddu_hsi = Newmarksuper_HSI2(Human,Bridge,numped,numbers,length,hht,pedvelocity,mped,kped,cped,xrb,linearMass)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[32], line 1
# ----> 1 _,_,ddu_hsi = Newmarksuper_HSI2(Human,Bridge,numped,numbers,length,hht,pedvelocity,mped,kped,cped,xrb,linearMass)
#
# File \\ad.monash.edu\home\User029\slok0019\Documents\pseudo excitation code for single pedestrian excitation\trial code 1\solver.py:417, in Newmarksuper_HSI2(case_pedestrian, case_bridge, numped, N_bridge, lb, hht, v, mped, kped, cped, xrb, rho)
#     412 a7 = gamma * h
#     414 #Mc = np.zeros((N_bridge+numped,N_bridge+numped))
#     415 #Mc[0:N_bridge, 0:N_bridge] = bridge.Mass_matrix()
# --> 417 Mc, Kc, Cc, Fc = MatrixAssemblesymetric(case_pedestrian,case_bridge,mped,kped,cped,xrb, lb, rho, N_bridge,numped,0)
#     418 #print(Mc)
#     419 #print(Kc)
#     420 #print(Cc)
#     421 #print(Fc)
#     422 # ddu0 = np.linalg.inv(Mc).dot(Fc - Cc.dot(du0) - Kc.dot(u0)) # same as inv(M)*(.)
#     423 NN=Phi_matrix(xrb,lb,rho,N_bridge,numped)
#
# File \\ad.monash.edu\home\User029\slok0019\Documents\pseudo excitation code for single pedestrian excitation\trial code 1\solver.py:359, in MatrixAssemblesymetric(case_pedestrian, case_bridge, mped, kped, cped, xrb, lb, rho, N_bridge, numped, t)
#     354 #end
#     355
#     356 #stiffness matrix
#     358 K1 = np.diag(kped)
# --> 359 K2 = -K1*NN
#     360 K3 = -(NN*K1).T
#     361 K4= np.hstack((K3,K1))
#
# ValueError: operands could not be broadcast together with shapes (2,2) (3,2)

# %%
              
accn_hsi = accdyn_super(Bridge,ddu_hsi,x_interested,hht)
#vertical_displacement = accdyn_super(Bridge,u,25,hht)

# %%
u,du,ddu = Newmarksuper_HSI2(Human,Bridge,numped,numbers,length,hht,pedvelocity,mped,[0],[0],xrb,linearMass)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 u,du,ddu = Newmarksuper_HSI2(Human,Bridge,numped,numbers,length,hht,pedvelocity,mped,[0],[0],xrb,linearMass)
#
# File \\ad.monash.edu\home\User029\slok0019\Documents\pseudo excitation code for single pedestrian excitation\trial code 1\solver.py:417, in Newmarksuper_HSI2(case_pedestrian, case_bridge, numped, N_bridge, lb, hht, v, mped, kped, cped, xrb, rho)
#     412 a7 = gamma * h
#     414 #Mc = np.zeros((N_bridge+numped,N_bridge+numped))
#     415 #Mc[0:N_bridge, 0:N_bridge] = bridge.Mass_matrix()
# --> 417 Mc, Kc, Cc, Fc = MatrixAssemblesymetric(case_pedestrian,case_bridge,mped,kped,cped,xrb, lb, rho, N_bridge,numped,0)
#     418 #print(Mc)
#     419 #print(Kc)
#     420 #print(Cc)
#     421 #print(Fc)
#     422 # ddu0 = np.linalg.inv(Mc).dot(Fc - Cc.dot(du0) - Kc.dot(u0)) # same as inv(M)*(.)
#     423 NN=Phi_matrix(xrb,lb,rho,N_bridge,numped)
#
# File \\ad.monash.edu\home\User029\slok0019\Documents\pseudo excitation code for single pedestrian excitation\trial code 1\solver.py:361, in MatrixAssemblesymetric(case_pedestrian, case_bridge, mped, kped, cped, xrb, lb, rho, N_bridge, numped, t)
#     359 K1 = np.diag(kped)
#     360 K2 = -kped*NN
# --> 361 K3 = -(NN.T)*kped[:,np.newaxis]   #-K1*(NN.T)
#     362 K4= np.hstack((K3,K1))
#     363 for i in range(numped):
#
# File c:\Users\slok0019\AppData\Local\miniconda3\envs\samadhi_basic\Lib\site-packages\numpy\core\shape_base.py:359, in hstack(tup, dtype, casting)
#     357     return _nx.concatenate(arrs, 0, dtype=dtype, casting=casting)
#     358 else:
# --> 359     return _nx.concatenate(arrs, 1, dtype=dtype, casting=casting)
#
# ValueError: all the input array dimensions except for the concatenation axis must match exactly, but along dimension 0, the array at index 0 has size 2 and the array at index 1 has size 1

# %%
               
accn = accdyn_super(Bridge,ddu,x_interested,hht)

# %%
t = np.arange(0, (length+1) / pedvelocity, hht)
plt.plot(t,accn , label ="without HSI" ,color='r')
plt.plot(t,accn_hsi,label ="with HSI",color='b')
plt.title("mid span acceleration")
plt.xlabel("time(s)")
plt.ylabel("m/s2")
plt.legend()
#plt.plot(t,vertical_displacement)  
plt.show()
#print("ddu",ddu)
#print("accn",accn)
